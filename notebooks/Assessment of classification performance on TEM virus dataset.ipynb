# %% [markdown]
# ## Initial setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
print(tf.__version__)
import torch
print(torch.__version__)
import matplotlib
print(matplotlib.__version__)

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# Other imports
! pip install tensorflow_addons
! pip install tensorflow_io

import os
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img

import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, AutoMinorLocator
from imutils import paths
from tqdm import tqdm
import tensorflow as tf
import tensorflow_addons as tfa
import tensorflow_datasets as tfds
import tensorflow_io as tfio
import tensorflow_hub as hub
import numpy as np
import cv2
import pandas as pd
import seaborn as sns
from scipy.stats import mannwhitneyu
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
import sklearn.manifold
from sklearn.metrics.pairwise import cosine_similarity as cos
from sympy.utilities.iterables import multiset_permutations
from sklearn.metrics import accuracy_score, f1_score,precision_score, recall_score, roc_auc_score, confusion_matrix
from sklearn.model_selection import *
from sklearn.preprocessing import StandardScaler
from IPython.display import Image, display

import zipfile
import concurrent.futures

# Random seed fix
random_seed = 42
tf.random.set_seed(random_seed)
np.random.seed(random_seed)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.17.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.8 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.17.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.26.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 123.4 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.26.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_io) (0.26.0)
# Installing collected packages: tensorflow-io
# Successfully installed tensorflow-io-0.26.0

# %% [markdown]
# ## Dataset gathering and preparation

# %%
# %cd /content/drive/MyDrive/nanowire-morphology-classification-project
# Out:
# /content/drive/MyDrive/nanowire-morphology-classification-project

# %%
training_batch_size = 4

BATCH_SIZE = training_batch_size

imageSize = 224

category_names = ['bundle', 'dispersed', 'network', 'singular']
color_method = ['C0', 'C1', 'C2', 'C3', 'C4']
color = ['black', 'magenta', 'cyan', 'yellow']
marker = ['o', 's', '<', '>', '^']
seaborn_palette = sns.color_palette("colorblind")

# %%
np.random.seed(random_seed)

peptide_morph_train_path = "/content/drive/MyDrive/TEM image datasets/2021-TEM virus/context_virus_1nm_256x256"
train_images_directory = np.array(list(paths.list_files(basePath=peptide_morph_train_path + "/augmented_train", validExts='jpg')))
validation_images_directory = np.array(list(paths.list_files(basePath=peptide_morph_train_path + "/validation", validExts='jpg')))
test_images_directory = np.array(list(paths.list_files(basePath=peptide_morph_train_path + "/test", validExts='jpg')))


print("number of training images: %i" % len(train_images_directory))
print("number of validation images: %i" % len(validation_images_directory))
print("number of test images: %i" % len(test_images_directory))
# Out:
# number of training images: 6553
# number of validation images: 1368
# number of test images: 1091

# %%
train_labels = []
validation_labels = []
test_labels = []
for i in range(train_images_directory.shape[0]):
  train_label = train_images_directory[i].split("/")[-2]
  train_labels.append(train_label)
le = LabelEncoder()
train_images_label = le.fit_transform(train_labels)

for i in range(validation_images_directory.shape[0]):
  validation_label = validation_images_directory[i].split("/")[-2]
  validation_labels.append(validation_label)
validation_images_label = le.transform(validation_labels)

for i in range(test_images_directory.shape[0]):
  test_label = test_images_directory[i].split("/")[-2]
  test_labels.append(test_label)
test_images_label = le.transform(test_labels)

# %%
# put training, validation and test data directory and labels in dataframes
train_label_storage = pd.DataFrame(np.concatenate((train_images_directory.reshape(1, -1).transpose(), train_images_label.reshape(1, -1).transpose()), axis=-1), columns=['filename', 'label'])
validation_label_storage = pd.DataFrame(np.concatenate((validation_images_directory.reshape(1, -1).transpose(), validation_images_label.reshape(1, -1).transpose()), axis=-1), columns=['filename', 'label'])
test_label_storage = pd.DataFrame(np.concatenate((test_images_directory.reshape(1, -1).transpose(), test_images_label.reshape(1, -1).transpose()), axis=-1), columns=['filename', 'label'])

# %%
# Image preprocessing utils
@tf.function
def parse_images(image_path):
    image_string = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image_string, channels=3)
    # image = tfio.experimental.image.decode_tiff(image_string)[:, :, :3]   # in the doc, it transforms tiff to 4 channels, with additional channel of opacity which is not needed.
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, size=[imageSize, imageSize])

    return image

# %%
train_ds = tf.data.Dataset.from_tensor_slices(train_images_directory)
train_ds = (
    train_ds
    .map(parse_images, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # .shuffle(200)
    .batch(training_batch_size
          #  , drop_remainder=True
           )
    .prefetch(tf.data.experimental.AUTOTUNE)
)

validation_ds = tf.data.Dataset.from_tensor_slices(validation_images_directory)
validation_ds = (
    validation_ds
    .map(parse_images, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # .shuffle(200)
    .batch(training_batch_size
          #  , drop_remainder=True
           )
    .prefetch(tf.data.experimental.AUTOTUNE)
)

test_ds = tf.data.Dataset.from_tensor_slices(test_images_directory)
test_ds = (
    test_ds
    .map(parse_images, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # .shuffle(200)
    .batch(training_batch_size
          #  , drop_remainder=True
           )
    .prefetch(tf.data.experimental.AUTOTUNE)
)

# %% [markdown]
# ## Initiate self-supervised models

# %%
Resnet50_transfer = tf.keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(imageSize, imageSize, 3), 
    pooling=None,
)

Resnet50_transfer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
# Resnet as backbone
def get_resnet_self_supervise_model(hidden_1, hidden_2, hidden_3):
    base_model = Resnet50_transfer
    base_model.trainable = True
    inputs = Input((imageSize, imageSize, 3))
    h = base_model(inputs, training=True)
    h = GlobalAveragePooling2D()(h)

    projection_1 = Dense(hidden_1)(h)                                        
    projection_1 = Activation("relu")(projection_1)
    projection_1 = BatchNormalization(epsilon=0.001)(projection_1)
    projection_2 = Dense(hidden_2)(projection_1)
    projection_2 = Activation("relu")(projection_2)
    projection_2 = BatchNormalization(epsilon=0.001)(projection_2)
    projection_3 = Dense(hidden_3)(projection_2)
    projection_3 = BatchNormalization(epsilon=0.001)(projection_3)

    resnet_model = Model(inputs, projection_3)
    
    return resnet_model

# %%
# state-of-the-arts simclr encoder trained on imagenet
saved_model_path = 'gs://simclr-checkpoints-tf2/simclrv2/pretrained/r50_1x_sk0/saved_model/'
imagenet_simclr_model = tf.saved_model.load(saved_model_path)

for image_batch in train_ds.take(1):
  simclr_logits = imagenet_simclr_model(image_batch, trainable=False)

simclr_layer_shape = simclr_logits['final_avg_pool'].shape[1]

# obtain feature maps from the state-of-the-arts simclr encoder trained on imagenet
train_feature = np.zeros((len(train_images_directory), simclr_layer_shape))
validation_feature = np.zeros((len(validation_images_directory), simclr_layer_shape))
test_feature = np.zeros((len(test_images_directory), simclr_layer_shape))

counter = 0
for train_image_batch in train_ds:
  train_feature[counter * training_batch_size: (counter + 1) * training_batch_size] = imagenet_simclr_model(train_image_batch, trainable=False)['final_avg_pool']
with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_5_layer_call_and_return_conditional_losses_12899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_37_layer_call_and_return_conditional_losses_34241) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_5_layer_call_and_return_conditional_losses_30337) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_34_layer_call_and_return_conditional_losses_33875) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_38_layer_call_and_return_conditional_losses_20159) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_9_layer_call_and_return_conditional_losses_30825) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_6_layer_call_and_return_conditional_losses_13119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_47_layer_call_and_return_conditional_losses_35461) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_32_layer_call_and_return_conditional_losses_33631) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_36_layer_call_and_return_conditional_losses_34119) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_13_layer_call_and_return_conditional_losses_14659) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_37_layer_call_and_return_conditional_losses_19939) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_33_layer_call_and_return_conditional_losses_33753) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_8_layer_call_and_return_conditional_losses_13559) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_53_layer_call_and_return_conditional_losses_23437) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_49_layer_call_and_return_conditional_losses_22579) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_13_layer_call_and_return_conditional_losses_31313) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_18_layer_call_and_return_conditional_losses_31923) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_47_layer_call_and_return_conditional_losses_22139) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_45_layer_call_and_return_conditional_losses_35217) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_27_layer_call_and_return_conditional_losses_33021) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_14_layer_call_and_return_conditional_losses_31435) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_36_layer_call_and_return_conditional_losses_19719) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_27_layer_call_and_return_conditional_losses_17739) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_20_layer_call_and_return_conditional_losses_32167) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_1_layer_call_and_return_conditional_losses_29849) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_55_layer_call_and_return_conditional_losses_23827) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_12_layer_call_and_return_conditional_losses_14439) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_35_layer_call_and_return_conditional_losses_19499) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_34_layer_call_and_return_conditional_losses_19279) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_2_layer_call_and_return_conditional_losses_12239) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_1_layer_call_and_return_conditional_losses_12019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_53_layer_call_and_return_conditional_losses_29513) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_12_layer_call_and_return_conditional_losses_31191) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_38_layer_call_and_return_conditional_losses_34363) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_11_layer_call_and_return_conditional_losses_31069) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_48_layer_call_and_return_conditional_losses_35583) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_55_layer_call_and_return_conditional_losses_29733) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_41_layer_call_and_return_conditional_losses_20819) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_3_layer_call_and_return_conditional_losses_12459) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_2_layer_call_and_return_conditional_losses_29971) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_9_layer_call_and_return_conditional_losses_13779) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_23_layer_call_and_return_conditional_losses_32533) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_54_layer_call_and_return_conditional_losses_23635) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_28_layer_call_and_return_conditional_losses_33143) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_39_layer_call_and_return_conditional_losses_34485) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_26_layer_call_and_return_conditional_losses_32899) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_30_layer_call_and_return_conditional_losses_33387) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_15_layer_call_and_return_conditional_losses_15099) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_45_layer_call_and_return_conditional_losses_21699) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_49_layer_call_and_return_conditional_losses_35705) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_18_layer_call_and_return_conditional_losses_15759) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_3_layer_call_and_return_conditional_losses_30093) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_sync_batch_normalization_44_layer_call_and_return_conditional_losses_21479) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.

# %% [markdown]
# ## Initiate downstream classification model

# %%
def get_linear_model(features):                                                                                  
    linear_model = Sequential([                                                                                  
			                              Input(shape=(features,)),
                                    # Dense(1024, activation='relu'),
                                    # Dropout(0.3),
                                    # Dense(1024, activation='relu'),
                                    # Dropout(0.3),
		                                Dense(9, activation="softmax")])
    return linear_model

# %% [markdown]
# ## Performance assessment of label-efficient training of downstream classification task in main manuscript

# %%
# Random seed fix
random_seed_list = np.array([42, 43, 44, 45, 46])
random_seed_for_split = np.linspace(42, 42 + 19, 20).astype(int)
training_image_size = np.array([600, 200, 120, 80, 40, 20, 10])

# list of models
models = ['barlow_tem', 'simclr_tem', 'barlow_ImageNet', 'simclr_ImageNet', 'simclr_ImageNet_sota']


earlystop_criterion = EarlyStopping(monitor='val_accuracy', patience=10, verbose=0, mode='auto', restore_best_weights=True)
adam = tf.keras.optimizers.Adam(learning_rate=0.001)
metrics = ['accuracy']

# %%
# for self-supervised models trained on tem images or ImageNet images (832 images) for TEM virus prediction
for m in range(0, 4):
  linear_scores = np.zeros((len(training_image_size), len(random_seed_list), len(random_seed_for_split), 4))
  fusion_matrix = np.zeros((len(training_image_size), len(random_seed_list), len(random_seed_for_split), 9, 9))
    
  for i in range(len(random_seed_list)):
    resnet_model = get_resnet_self_supervise_model(128, 64, 1024)
    if models[m] == 'barlow_tem':
      resnet_model.load_weights('barlow_resnet_batch64_project128_64_1024_seed%i.h5' % (random_seed_list[i]))
    if models[m] == 'simclr_tem':
      resnet_model.load_weights('simclr_resnet_batch64_project128_64_1024_nocrop_seed%i.h5' % (random_seed_list[i]))
    if models[m] == 'barlow_ImageNet':
      resnet_model.load_weights('%s_batch64_project128_64_1024_seed%i.h5' % (models[m], random_seed_list[i]))
    if models[m] == 'simclr_ImageNet':
      resnet_model.load_weights('%s_batch64_project128_64_1024_nocrop_seed%i.h5' % (models[m], random_seed_list[i]))


    resnet_model.layers[1].trainable = False

    feature_extraction_model = Model(resnet_model.input, resnet_model.layers[-9].output)

    # Extract train and test features
    train_feature = feature_extraction_model.predict(train_ds)
    validation_feature = feature_extraction_model.predict(validation_ds)
    test_feature = feature_extraction_model.predict(test_ds)

    for j in range(len(random_seed_for_split)):
      for n in range(len(training_image_size)):
        train_images_directory = train_label_storage.groupby('label').sample(n=training_image_size[n], random_state = random_seed_for_split[j]).sample(frac=1, random_state = 42)['filename'].to_numpy().astype(str)
        train_images_label = train_label_storage.groupby('label').sample(n=training_image_size[n], random_state = random_seed_for_split[j]).sample(frac=1, random_state = 42)['label'].to_numpy().astype(int)

        checkpoint_model_linear = ModelCheckpoint('TEM-virus-best_classify_models/%s_%iper_class_seed%i_seed%i_linear.h5' 
                                      % (models[m], training_image_size[n], random_seed_list[i], random_seed_for_split[j]),
                                      monitor='val_accuracy', mode='auto', verbose=0, save_best_only=True, save_weights_only=True)
        train_feature_map = train_feature[train_label_storage.groupby('label').sample(training_image_size[n], random_state = random_seed_for_split[j]).sample(frac=1, random_state = 42).index.to_numpy()]
        # train linear classifier model
        linear_model = get_linear_model(train_feature.shape[1])
        linear_model.compile(loss="sparse_categorical_crossentropy", metrics=metrics, optimizer=adam)
        linear_history = linear_model.fit(train_feature_map, train_images_label, validation_data=(validation_feature, validation_images_label), 
                                              batch_size=training_batch_size, epochs=300, workers=8, use_multiprocessing=True, 
                                              verbose=1, callbacks=[earlystop_criterion, checkpoint_model_linear])
        # log best classification model performance
        linear_model.load_weights('TEM-virus-best_classify_models/%s_%iper_class_seed%i_seed%i_linear.h5' 
                                    % (models[m], training_image_size[n], random_seed_list[i], random_seed_for_split[j]))
        y_pred_linear = np.argmax(linear_model.predict(test_feature), axis=-1)

        linear_scores[n, i, j] = np.array([accuracy_score(y_pred_linear, test_images_label), 
                                                precision_score(y_pred_linear, test_images_label, average='weighted'), 
                                                recall_score(y_pred_linear, test_images_label, average='weighted'),
                                                f1_score(y_pred_linear, test_images_label, average='weighted')])
        fusion_matrix[n, i, j] = confusion_matrix(y_pred_linear, test_images_label)
    
          
  np.savez_compressed('TEM-virus-classify_scores/%s_classification_result.npz' %(models[m]), scores=linear_scores, fusion_matrix=fusion_matrix)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 6/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.2974 - accuracy: 0.8972 - val_loss: 0.8798 - val_accuracy: 0.7376
# Epoch 7/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.2618 - accuracy: 0.9097 - val_loss: 1.0261 - val_accuracy: 0.6893
# Epoch 8/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.2553 - accuracy: 0.9069 - val_loss: 0.7462 - val_accuracy: 0.8158
# Epoch 9/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.2588 - accuracy: 0.9125 - val_loss: 0.7475 - val_accuracy: 0.7763
# Epoch 10/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.2137 - accuracy: 0.9306 - val_loss: 0.9362 - val_accuracy: 0.6864
# Epoch 11/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2016 - accuracy: 0.9347 - val_loss: 0.7281 - val_accuracy: 0.7785
# Epoch 12/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.1827 - accuracy: 0.9389 - val_loss: 0.7046 - val_accuracy: 0.8129
# Epoch 13/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1822 - accuracy: 0.9347 - val_loss: 0.6514 - val_accuracy: 0.8304
# Epoch 14/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1594 - accuracy: 0.9597 - val_loss: 0.6875 - val_accuracy: 0.8107
# Epoch 15/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1422 - accuracy: 0.9542 - val_loss: 0.6908 - val_accuracy: 0.7990
# Epoch 16/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.1413 - accuracy: 0.9611 - val_loss: 0.7635 - val_accuracy: 0.7939
# Epoch 17/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.1216 - accuracy: 0.9708 - val_loss: 0.7620 - val_accuracy: 0.8041
# Epoch 18/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1375 - accuracy: 0.9556 - val_loss: 0.8291 - val_accuracy: 0.7844
# Epoch 19/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.1101 - accuracy: 0.9722 - val_loss: 0.7392 - val_accuracy: 0.8107
# Epoch 20/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.1153 - accuracy: 0.9681 - val_loss: 0.9140 - val_accuracy: 0.7968
# Epoch 21/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.1169 - accuracy: 0.9639 - val_loss: 0.7648 - val_accuracy: 0.8136
# Epoch 22/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.1120 - accuracy: 0.9722 - val_loss: 0.6974 - val_accuracy: 0.8311
# Epoch 23/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.1136 - accuracy: 0.9653 - val_loss: 0.9354 - val_accuracy: 0.7558
# Epoch 24/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.1029 - accuracy: 0.9750 - val_loss: 0.9435 - val_accuracy: 0.7544
# Epoch 25/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.0851 - accuracy: 0.9722 - val_loss: 0.8393 - val_accuracy: 0.7961
# Epoch 26/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.0801 - accuracy: 0.9778 - val_loss: 0.8336 - val_accuracy: 0.8231
# Epoch 27/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0812 - accuracy: 0.9778 - val_loss: 0.7329 - val_accuracy: 0.8487
# Epoch 28/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.1305 - accuracy: 0.9597 - val_loss: 1.6062 - val_accuracy: 0.7003
# Epoch 29/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.1327 - accuracy: 0.9569 - val_loss: 0.9860 - val_accuracy: 0.7120
# Epoch 30/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.0979 - accuracy: 0.9639 - val_loss: 0.6943 - val_accuracy: 0.8355
# Epoch 31/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0715 - accuracy: 0.9833 - val_loss: 0.7530 - val_accuracy: 0.8151
# Epoch 32/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.
300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.3225 - accuracy: 0.8833 - val_loss: 1.2471 - val_accuracy: 0.6447
# Epoch 8/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3908 - accuracy: 0.8833 - val_loss: 1.4211 - val_accuracy: 0.6308
# Epoch 9/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.3611 - accuracy: 0.8667 - val_loss: 1.2709 - val_accuracy: 0.6499
# Epoch 10/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.2441 - accuracy: 0.9111 - val_loss: 1.1247 - val_accuracy: 0.6857
# Epoch 11/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.2577 - accuracy: 0.9056 - val_loss: 1.0486 - val_accuracy: 0.7266
# Epoch 12/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.2237 - accuracy: 0.9500 - val_loss: 1.1954 - val_accuracy: 0.6776
# Epoch 13/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.2016 - accuracy: 0.9222 - val_loss: 1.1163 - val_accuracy: 0.7003
# Epoch 14/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1619 - accuracy: 0.9611 - val_loss: 1.0081 - val_accuracy: 0.7171
# Epoch 15/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.1787 - accuracy: 0.9667 - val_loss: 1.0330 - val_accuracy: 0.7317
# Epoch 16/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.1551 - accuracy: 0.9500 - val_loss: 1.4250 - val_accuracy: 0.6184
# Epoch 17/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1563 - accuracy: 0.9500 - val_loss: 0.9672 - val_accuracy: 0.7368
# Epoch 18/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1285 - accuracy: 0.9667 - val_loss: 1.1477 - val_accuracy: 0.6827
# Epoch 19/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1428 - accuracy: 0.9667 - val_loss: 1.1548 - val_accuracy: 0.7098
# Epoch 20/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1150 - accuracy: 0.9722 - val_loss: 1.0732 - val_accuracy: 0.7193
# Epoch 21/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1186 - accuracy: 0.9722 - val_loss: 1.0384 - val_accuracy: 0.7383
# Epoch 22/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0955 - accuracy: 0.9889 - val_loss: 1.1011 - val_accuracy: 0.7149
# Epoch 23/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0979 - accuracy: 0.9833 - val_loss: 1.4525 - val_accuracy: 0.6345
# Epoch 24/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1102 - accuracy: 0.9667 - val_loss: 1.0887 - val_accuracy: 0.7193
# Epoch 25/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1000 - accuracy: 0.9778 - val_loss: 1.2184 - val_accuracy: 0.6827
# Epoch 26/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0802 - accuracy: 1.0000 - val_loss: 1.0608 - val_accuracy: 0.7142
# Epoch 27/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0841 - accuracy: 0.9889 - val_loss: 1.1664 - val_accuracy: 0.6849
# Epoch 28/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0859 - accuracy: 0.9833 - val_loss: 1.0595 - val_accuracy: 0.7193
# Epoch 29/300
# 45/45 [==============================] - 1s 13ms/step - loss: 0.0757 - accuracy: 0.9833 - val_loss: 1.0698 - val_accuracy: 0.7156
# Epoch 30/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0768 - accuracy: 0.9833 - val_loss: 1.1449 - val_accuracy: 0.7076
# Epoch 31/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0802 - accuracy: 0.9889 - val_loss: 1.0433 - val_accuracy: 0.7398
# Epoch 32/300
# 45/45 [==============================] - 1s 14ms/step - loss: 0.0824 - accuracy: 0.9889 - val_loss: 1.1017 - val_accuracy: 0.7303
# Epoch 33/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0712 - accuracy: 0.9944 - val_loss: 1.1301 - val_accuracy: 0.7061
# Epoch 34/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0626 - accuracy: 0.9944 - val_loss: 1.1043 - val_accuracy: 0.7273
# Epoch 35/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0585 - accuracy: 0.9944 - val_loss: 1.0671 - val_accuracy: 0.7266
# Epoch 36/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0656 - accuracy: 0.9944 - val_loss: 1.1067 - val_accuracy: 0.7215
# Epoch 37/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.
300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.3620 - accuracy: 0.8667 - val_loss: 1.1210 - val_accuracy: 0.6659
# Epoch 8/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.2481 - accuracy: 0.9222 - val_loss: 1.3205 - val_accuracy: 0.6031
# Epoch 9/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.2227 - accuracy: 0.9222 - val_loss: 1.1742 - val_accuracy: 0.6389
# Epoch 10/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.2138 - accuracy: 0.9444 - val_loss: 0.9303 - val_accuracy: 0.7083
# Epoch 11/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1767 - accuracy: 0.9500 - val_loss: 0.9413 - val_accuracy: 0.7120
# Epoch 12/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.1612 - accuracy: 0.9556 - val_loss: 1.2374 - val_accuracy: 0.6367
# Epoch 13/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.1710 - accuracy: 0.9611 - val_loss: 1.1510 - val_accuracy: 0.6594
# Epoch 14/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1387 - accuracy: 0.9556 - val_loss: 0.9629 - val_accuracy: 0.7200
# Epoch 15/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.1231 - accuracy: 0.9611 - val_loss: 1.0586 - val_accuracy: 0.6806
# Epoch 16/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.1274 - accuracy: 0.9833 - val_loss: 1.3947 - val_accuracy: 0.5914
# Epoch 17/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1350 - accuracy: 0.9556 - val_loss: 1.0036 - val_accuracy: 0.6981
# Epoch 18/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.1295 - accuracy: 0.9667 - val_loss: 1.0030 - val_accuracy: 0.7076
# Epoch 19/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.1191 - accuracy: 0.9778 - val_loss: 1.0226 - val_accuracy: 0.7018
# Epoch 20/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0949 - accuracy: 0.9833 - val_loss: 0.9568 - val_accuracy: 0.7222
# Epoch 21/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0790 - accuracy: 0.9944 - val_loss: 1.2408 - val_accuracy: 0.6513
# Epoch 22/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1089 - accuracy: 0.9722 - val_loss: 1.0021 - val_accuracy: 0.7105
# Epoch 23/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0949 - accuracy: 0.9833 - val_loss: 1.1475 - val_accuracy: 0.6645
# Epoch 24/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0897 - accuracy: 0.9944 - val_loss: 0.9763 - val_accuracy: 0.7171
# Epoch 25/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0636 - accuracy: 0.9944 - val_loss: 1.0133 - val_accuracy: 0.7098
# Epoch 26/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0721 - accuracy: 0.9944 - val_loss: 1.0120 - val_accuracy: 0.7032
# Epoch 27/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0657 - accuracy: 0.9944 - val_loss: 1.0382 - val_accuracy: 0.7054
# Epoch 28/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 1.0243 - val_accuracy: 0.7120
# Epoch 29/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0606 - accuracy: 0.9944 - val_loss: 0.9925 - val_accuracy: 0.7032
# Epoch 30/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0806 - accuracy: 0.9889 - val_loss: 1.0482 - val_accuracy: 0.6974
# Epoch 1/300
# 23/23 [==============================] - 1s 37ms/step - loss: 4.9586 - accuracy: 0.1667 - val_loss: 3.9722 - val_accuracy: 0.2244
# Epoch 2/300
# 23/23 [==============================] - 1s 31ms/step - loss: 2.2295 - accuracy: 0.4556 - val_loss: 2.9544 - val_accuracy: 0.3735
# Epoch 3/300
# 23/23 [==============================] - 0s 20ms/step - loss: 1.3097 - accuracy: 0.6111 - val_loss: 1.7608 - val_accuracy: 0.5395
# Epoch 4/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.8174 - accuracy: 0.7778 - val_loss: 1.9348 - val_accuracy: 0.5314
# Epoch 5/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.4516 - accuracy: 0.8778 - val_loss: 2.6738 - val_accuracy: 0.3618
# Epoch 6/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.4866 - accuracy: 0.8556 - val_loss: 1.5888 - val_accuracy: 0.5687
# Epoch 7/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.3008 - accuracy: 0.9333 - val_loss: 1.5149 - val_accuracy: 0.5855
# Epoch 8/300
# 23/23 [==============================] - 0s 22ms/step - loss: 0.2040 - accuracy: 0.9444 - val_loss: 1.3180 - val_accuracy: 0.6206
# Epoch 9/300
# 23/23 [==============================] - 0s 22ms/step - loss: 0.2028 - accuracy: 0.9444 - val_loss: 1.2545 - val_accuracy: 0.6462
# Epoch 10/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.2136 - accuracy: 0.9444 - val_loss: 1.3759 - val_accuracy: 0.6192
# Epoch 11/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.1187 - accuracy: 0.9778 - val_loss: 1.2658 - val_accuracy: 0.6330
# Epoch 12/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.1335 - accuracy: 0.9889 - val_loss: 1.3240 - val_accuracy: 0.6301
# Epoch 13/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.1115 - accuracy: 0.9889 - val_loss: 1.3156 - val_accuracy: 0.6330
# Epoch 14/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.1016 - accuracy: 0.9778 - val_loss: 1.2903 - val_accuracy: 0.6382
# Epoch 15/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0917 - accuracy: 1.0000 - val_loss: 1.3430 - val_accuracy: 0.6338
# Epoch 16/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0928 - accuracy: 0.9778 - val_loss: 1.2487 - val_accuracy: 0.6513
# Epoch 17/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.1070 - accuracy: 0.9778 - val_loss: 1.2646 - val_accuracy: 0.6440
# Epoch 18/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0824 - accuracy: 1.0000 - val_loss: 1.3405 - val_accuracy: 0.6323
# Epoch 19/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0699 - accuracy: 1.0000 - val_loss: 1.3449 - val_accuracy: 0.6382
# Epoch 20/300
# 23/23 [==============================] - 0s 22ms/step - loss: 0.0719 - accuracy: 1.0000 - val_loss: 1.4412 - val_accuracy: 0.6045
# Epoch 21/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0824 - accuracy: 0.9778 - val_loss: 1.4175 - val_accuracy: 0.6170
# Epoch 22/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0627 - accuracy: 1.0000 - val_loss: 1.4314 - val_accuracy: 0.6045
# Epoch 23/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0584 - accuracy: 1.0000 - val_loss: 1.2941 - val_accuracy: 0.6447
# Epoch 24/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0528 - accuracy: 1.0000 - val_loss: 1.3266 - val_accuracy: 0.6418
# Epoch 25/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0521 - accuracy: 1.0000 - val_loss: 1.3929 - val_accuracy: 0.6243
# Epoch 26/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0531 - accuracy: 1.0000 - val_loss: 1.2873 - val_accuracy: 0.6499
# [0.92942255 0.93082443 0.92942255 0.92886886]
# [[ 49.   0.   0.   0.   0.   7.   0.   1.   0.]
#  [  5.  77.   0.   3.   0.   0.   0.   0.   6.]
#  [  0.   0.  45.   0.   0.   0.   1.   0.   0.]
#  [  0.   0.   0. 154.   5.   1.   0.   0.   0.]
#  [  0.   0.   3.   1.  28.   0.   0.   0.   9.]
#  [  9.   0.   0.   1.   0.  73.   0.   0.   0.]
#  [  0.   0.   8.   0.   0.   0.  28.   0.   0.]
#  [  0.   1.   0.   0.   0.   0.   0. 184.   0.]
#  [  0.   8.   0.   7.   0.   0.   0.   1. 376.]]

# %%
# Random seed fix
random_seed_list = np.array([42, 43, 44, 45, 46])
random_seed_for_split = np.linspace(42, 42 + 99, 100).astype(int)
training_image_size = np.array([600, 200, 120, 80, 40, 20, 10])

# list of models
models = ['barlow_tem', 'simclr_tem', 'barlow_ImageNet', 'simclr_ImageNet', 'simclr_ImageNet_sota']


earlystop_criterion = EarlyStopping(monitor='val_accuracy', patience=10, verbose=0, mode='auto', restore_best_weights=True)
adam = tf.keras.optimizers.Adam(learning_rate=0.001)
metrics = ['accuracy']

# %%
# for sota self-supervised encoder obtained from SimCLR official implementation

linear_scores = np.zeros((len(training_image_size), len(random_seed_for_split), 4))
fusion_matrix = np.zeros((len(training_image_size), len(random_seed_for_split), 9, 9))

for j in range(len(random_seed_for_split)):
  for n in range(len(training_image_size)):
    train_images_directory = train_label_storage.groupby('label').sample(n=training_image_size[n], random_state = random_seed_for_split[j]).sample(frac=1, random_state = 42)['filename'].to_numpy().astype(str)
    train_images_label = train_label_storage.groupby('label').sample(n=training_image_size[n], random_state = random_seed_for_split[j]).sample(frac=1, random_state = 42)['label'].to_numpy().astype(int)

    checkpoint_model_linear = ModelCheckpoint('TEM-virus-best_classify_models/%s_%iper_class_seed%i_linear.h5' 
                                  % (models[-1], training_image_size[n], random_seed_for_split[j]),
                                  monitor='val_accuracy', mode='auto', verbose=0, save_best_only=True, save_weights_only=True)
    train_feature_map = train_feature[train_label_storage.groupby('label').sample(training_image_size[n], random_state = random_seed_for_split[j]).sample(frac=1, random_state = 42).index.to_numpy()]
    # train linear classifier model
    linear_model = get_linear_model(train_feature.shape[1])
    linear_model.compile(loss="sparse_categorical_crossentropy", metrics=metrics, optimizer=adam)
    linear_history = linear_model.fit(train_feature_map, train_images_label, validation_data=(validation_feature, validation_images_label), 
                                          batch_size=training_batch_size, epochs=300, workers=8, use_multiprocessing=True, 
                                          verbose=1, callbacks=[earlystop_criterion, checkpoint_model_linear])
    # log best classification model performance
    linear_model.load_weights('TEM-virus-best_classify_models/%s_%iper_class_seed%i_linear.h5' 
                                % (models[-1], training_image_size[n], random_seed_for_split[j]))
    y_pred_linear = np.argmax(linear_model.predict(test_feature), axis=-1)

    linear_scores[n, j] = np.array([accuracy_score(y_pred_linear, test_images_label), 
                                            precision_score(y_pred_linear, test_images_label, average='weighted'), 
                                            recall_score(y_pred_linear, test_images_label, average='weighted'),
                                            f1_score(y_pred_linear, test_images_label, average='weighted')])

  np.savez_compressed('TEM-virus-classify_scores/%s_classification_result.npz' %(models[-1]), scores=linear_scores, fusion_matrix=fusion_matrix)
# Out:
# Streaming output truncated to the last 5000 lines.
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0751 - accuracy: 1.0000 - val_loss: 0.5371 - val_accuracy: 0.8626
# Epoch 16/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.5338 - val_accuracy: 0.8582
# Epoch 17/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0651 - accuracy: 1.0000 - val_loss: 0.5302 - val_accuracy: 0.8575
# Epoch 18/300
# 23/23 [==============================] - 1s 23ms/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.5147 - val_accuracy: 0.8618
# Epoch 19/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0574 - accuracy: 1.0000 - val_loss: 0.5170 - val_accuracy: 0.8596
# Epoch 20/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.5089 - val_accuracy: 0.8618
# Epoch 21/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.5066 - val_accuracy: 0.8626
# Epoch 22/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 0.4934 - val_accuracy: 0.8655
# Epoch 23/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 0.4949 - val_accuracy: 0.8640
# Epoch 24/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0439 - accuracy: 1.0000 - val_loss: 0.4956 - val_accuracy: 0.8626
# Epoch 25/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.4882 - val_accuracy: 0.8618
# Epoch 26/300
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.4910 - val_accuracy: 0.8618
# Epoch 27/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.4902 - val_accuracy: 0.8611
# Epoch 28/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.4877 - val_accuracy: 0.8618
# Epoch 29/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.4827 - val_accuracy: 0.8618
# Epoch 30/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.4754 - val_accuracy: 0.8626
# Epoch 31/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 0.4788 - val_accuracy: 0.8618
# Epoch 32/300
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.4679 - val_accuracy: 0.8655
# Epoch 1/300
# 1350/1350 [==============================] - 4s 2ms/step - loss: 0.2885 - accuracy: 0.9411 - val_loss: 0.2770 - val_accuracy: 0.9232
# Epoch 2/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0989 - accuracy: 0.9854 - val_loss: 0.2220 - val_accuracy: 0.9342
# Epoch 3/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0627 - accuracy: 0.9924 - val_loss: 0.2330 - val_accuracy: 0.9408
# Epoch 4/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0427 - accuracy: 0.9954 - val_loss: 0.2124 - val_accuracy: 0.9437
# Epoch 5/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0307 - accuracy: 0.9972 - val_loss: 0.2108 - val_accuracy: 0.9437
# Epoch 6/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0223 - accuracy: 0.9985 - val_loss: 0.1896 - val_accuracy: 0.9415
# Epoch 7/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0166 - accuracy: 0.9989 - val_loss: 0.1915 - val_accuracy: 0.9481
# Epoch 8/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0125 - accuracy: 0.9998 - val_loss: 0.2079 - val_accuracy: 0.9466
# Epoch 9/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.9430
# Epoch 10/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0074 - accuracy: 0.9998 - val_loss: 0.2174 - val_accuracy: 0.9444
# Epoch 11/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2331 - val_accuracy: 0.9459
# Epoch 12/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2203 - val_accuracy: 0.9452
# Epoch 13/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2461 - val_accuracy: 0.9481
# Epoch 14/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2576 - val_accuracy: 0.9452
# Epoch 15/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.9466
# Epoch 16/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2549 - val_accuracy: 0.9474
# Epoch 17/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2720 - val_accuracy: 0.9466
# Epoch 1/300
# 450/450 [==============================] - 2s 3ms/step - loss: 0.5165 - accuracy: 0.8739 - val_loss: 0.3763 - val_accuracy: 0.9050
# Epoch 2/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.1869 - accuracy: 0.9711 - val_loss: 0.3435 - val_accuracy: 0.9108
# Epoch 3/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.1303 - accuracy: 0.9800 - val_loss: 0.2985 - val_accuracy: 0.9203
# Epoch 4/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0995 - accuracy: 0.9894 - val_loss: 0.2881 - val_accuracy: 0.9247
# Epoch 5/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0788 - accuracy: 0.9917 - val_loss: 0.2878 - val_accuracy: 0.9218
# Epoch 6/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0644 - accuracy: 0.9944 - val_loss: 0.2770 - val_accuracy: 0.9313
# Epoch 7/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0532 - accuracy: 0.9972 - val_loss: 0.2536 - val_accuracy: 0.9313
# Epoch 8/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0445 - accuracy: 0.9972 - val_loss: 0.2680 - val_accuracy: 0.9284
# Epoch 9/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0376 - accuracy: 0.9978 - val_loss: 0.2776 - val_accuracy: 0.9276
# Epoch 10/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0318 - accuracy: 0.9983 - val_loss: 0.2594 - val_accuracy: 0.9349
# Epoch 11/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0269 - accuracy: 0.9983 - val_loss: 0.2611 - val_accuracy: 0.9291
# Epoch 12/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.9335
# Epoch 13/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0196 - accuracy: 0.9989 - val_loss: 0.2713 - val_accuracy: 0.9298
# Epoch 14/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.2590 - val_accuracy: 0.9327
# Epoch 15/300
# 450/450 [==============================] - 2s 3ms/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 0.2530 - val_accuracy: 0.9349
# Epoch 16/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.2685 - val_accuracy: 0.9335
# Epoch 17/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.2595 - val_accuracy: 0.9320
# Epoch 18/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2793 - val_accuracy: 0.9306
# Epoch 19/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9342
# Epoch 20/300
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.2749 - val_accuracy: 0.9364
# Epoch 21/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2766 - val_accuracy: 0.9313
# Epoch 22/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.2742 - val_accuracy: 0.9327
# Epoch 23/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2886 - val_accuracy: 0.9357
# Epoch 24/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2931 - val_accuracy: 0.9342
# Epoch 25/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2893 - val_accuracy: 0.9320
# Epoch 26/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2857 - val_accuracy: 0.9349
# Epoch 27/300
# 450/450 [==============================] - 2s 3ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.3020 - val_accuracy: 0.9364
# Epoch 28/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.3002 - val_accuracy: 0.9327
# Epoch 29/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3007 - val_accuracy: 0.9357
# Epoch 30/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3157 - val_accuracy: 0.9313
# Epoch 1/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.6411 - accuracy: 0.8324 - val_loss: 0.4483 - val_accuracy: 0.8947
# Epoch 2/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.2328 - accuracy: 0.9713 - val_loss: 0.3587 - val_accuracy: 0.9167
# Epoch 3/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.1592 - accuracy: 0.9833 - val_loss: 0.3264 - val_accuracy: 0.9145
# Epoch 4/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.1242 - accuracy: 0.9889 - val_loss: 0.3146 - val_accuracy: 0.9218
# Epoch 5/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0997 - accuracy: 0.9926 - val_loss: 0.3256 - val_accuracy: 0.9181
# Epoch 6/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0841 - accuracy: 0.9944 - val_loss: 0.2941 - val_accuracy: 0.9247
# Epoch 7/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0711 - accuracy: 0.9963 - val_loss: 0.3085 - val_accuracy: 0.9218
# Epoch 8/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0604 - accuracy: 0.9954 - val_loss: 0.2798 - val_accuracy: 0.9276
# Epoch 9/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0534 - accuracy: 0.9972 - val_loss: 0.2803 - val_accuracy: 0.9262
# Epoch 10/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0458 - accuracy: 0.9981 - val_loss: 0.2820 - val_accuracy: 0.9262
# Epoch 11/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0407 - accuracy: 0.9981 - val_loss: 0.2785 - val_accuracy: 0.9262
# Epoch 12/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0353 - accuracy: 0.9991 - val_loss: 0.2658 - val_accuracy: 0.9276
# Epoch 13/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0315 - accuracy: 0.9981 - val_loss: 0.2835 - val_accuracy: 0.9284
# Epoch 14/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0278 - accuracy: 0.9991 - val_loss: 0.2801 - val_accuracy: 0.9284
# Epoch 15/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.2635 - val_accuracy: 0.9284
# Epoch 16/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.2699 - val_accuracy: 0.9276
# Epoch 17/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.2698 - val_accuracy: 0.9269
# Epoch 18/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.2701 - val_accuracy: 0.9306
# Epoch 19/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.2681 - val_accuracy: 0.9313
# Epoch 20/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.2829 - val_accuracy: 0.9240
# Epoch 21/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.2761 - val_accuracy: 0.9262
# Epoch 22/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2733 - val_accuracy: 0.9269
# Epoch 23/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2720 - val_accuracy: 0.9291
# Epoch 24/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.2696 - val_accuracy: 0.9313
# Epoch 25/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2771 - val_accuracy: 0.9320
# Epoch 26/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.2740 - val_accuracy: 0.9284
# Epoch 27/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.2757 - val_accuracy: 0.9276
# Epoch 28/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2666 - val_accuracy: 0.9313
# Epoch 29/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.
300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1115 - accuracy: 0.9917 - val_loss: 0.3914 - val_accuracy: 0.8999
# Epoch 8/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0975 - accuracy: 0.9917 - val_loss: 0.3905 - val_accuracy: 0.8991
# Epoch 9/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0849 - accuracy: 0.9972 - val_loss: 0.3833 - val_accuracy: 0.9020
# Epoch 10/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0765 - accuracy: 1.0000 - val_loss: 0.3789 - val_accuracy: 0.9013
# Epoch 11/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0686 - accuracy: 1.0000 - val_loss: 0.3731 - val_accuracy: 0.9013
# Epoch 12/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.3640 - val_accuracy: 0.9028
# Epoch 13/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0570 - accuracy: 1.0000 - val_loss: 0.3689 - val_accuracy: 0.8999
# Epoch 14/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.3657 - val_accuracy: 0.8999
# Epoch 15/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0475 - accuracy: 1.0000 - val_loss: 0.3587 - val_accuracy: 0.9035
# Epoch 16/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.3519 - val_accuracy: 0.9050
# Epoch 17/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0405 - accuracy: 1.0000 - val_loss: 0.3541 - val_accuracy: 0.9013
# Epoch 18/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.3515 - val_accuracy: 0.9035
# Epoch 19/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.3418 - val_accuracy: 0.9050
# Epoch 20/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.3439 - val_accuracy: 0.9042
# Epoch 21/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0307 - accuracy: 1.0000 - val_loss: 0.3407 - val_accuracy: 0.9042
# Epoch 22/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.3452 - val_accuracy: 0.9020
# Epoch 23/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.3448 - val_accuracy: 0.9020
# Epoch 24/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.3384 - val_accuracy: 0.9050
# Epoch 25/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.3346 - val_accuracy: 0.9057
# Epoch 26/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.3359 - val_accuracy: 0.9042
# Epoch 27/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.3341 - val_accuracy: 0.9042
# Epoch 28/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.3294 - val_accuracy: 0.9050
# Epoch 29/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.3302 - val_accuracy: 0.9050
# Epoch 30/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.3316 - val_accuracy: 0.9050
# Epoch 31/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.3340 - val_accuracy: 0.9035
# Epoch 32/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.3347 - val_accuracy: 0.9028
# Epoch 33/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.3312 - val_accuracy: 0.9050
# Epoch 34/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.3348 - val_accuracy: 0.9020
# Epoch 35/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.3280 - val_accuracy: 0.9057
# Epoch 1/300
# 45/45 [==============================] - 1s 13ms/step - loss: 1.4021 - accuracy: 0.5056 - val_loss: 0.9749 - val_accuracy: 0.6813
# Epoch 2/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.4782 - accuracy: 0.9444 - val_loss: 0.6635 - val_accuracy: 0.8428
# Epoch 3/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.3029 - accuracy: 0.9778 - val_loss: 0.6205 - val_accuracy: 0.8516
# Epoch 4/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.2303 - accuracy: 0.9833 - val_loss: 0.5797 - val_accuracy: 0.8523
# Epoch 5/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1873 - accuracy: 0.9889 - val_loss: 0.5608 - val_accuracy: 0.8567
# Epoch 6/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1554 - accuracy: 0.9944 - val_loss: 0.5268 - val_accuracy: 0.8633
# Epoch 7/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1320 - accuracy: 1.0000 - val_loss: 0.4987 - val_accuracy: 0.8713
# Epoch 8/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1162 - accuracy: 1.0000 - val_loss: 0.4889 - val_accuracy: 0.8743
# Epoch 9/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1009 - accuracy: 1.0000 - val_loss: 0.4803 - val_accuracy: 0.8735
# Epoch 10/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0918 - accuracy: 1.0000 - val_loss: 0.4734 - val_accuracy: 0.8706
# Epoch 11/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0833 - accuracy: 1.0000 - val_loss: 0.4558 - val_accuracy: 0.8779
# Epoch 12/300
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 0.4521 - val_accuracy: 0.8765
# Epoch 13/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0685 - accuracy: 1.0000 - val_loss: 0.4528 - val_accuracy: 0.8750
# Epoch 14/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 0.4414 - val_accuracy: 0.8765
# Epoch 15/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0583 - accuracy: 1.0000 - val_loss: 0.4406 - val_accuracy: 0.8765
# Epoch 16/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0548 - accuracy: 1.0000 - val_loss: 0.4339 - val_accuracy: 0.8772
# Epoch 17/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0515 - accuracy: 1.0000 - val_loss: 0.4363 - val_accuracy: 0.8765
# Epoch 18/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0483 - accuracy: 1.0000 - val_loss: 0.4294 - val_accuracy: 0.8787
# Epoch 19/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.4321 - val_accuracy: 0.8779
# Epoch 20/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0422 - accuracy: 1.0000 - val_loss: 0.4253 - val_accuracy: 0.8808
# Epoch 21/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0395 - accuracy: 1.0000 - val_loss: 0.4175 - val_accuracy: 0.8823
# Epoch 22/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.4213 - val_accuracy: 0.8787
# Epoch 23/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 0.4101 - val_accuracy: 0.8852
# Epoch 24/300
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.4105 - val_accuracy: 0.8830
# Epoch 25/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.4094 - val_accuracy: 0.8816
# Epoch 26/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.4115 - val_accuracy: 0.8801
# Epoch 27/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.4091 - val_accuracy: 0.8830
# Epoch 28/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.4106 - val_accuracy: 0.8816
# Epoch 29/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.4031 - val_accuracy: 0.8816
# Epoch 30/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.4034 - val_accuracy: 0.8838
# Epoch 31/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.4004 - val_accuracy: 0.8816
# Epoch 32/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.4023 - val_accuracy: 0.8816
# Epoch 33/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.4002 - val_accuracy: 0.8794
# Epoch 1/300
# 23/23 [==============================] - 1s 25ms/step - loss: 1.8403 - accuracy: 0.3667 - val_loss: 1.1775 - val_accuracy: 0.6915
# Epoch 2/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.7233 - accuracy: 0.8667 - val_loss: 0.9666 - val_accuracy: 0.7354
# Epoch 3/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.3949 - accuracy: 0.9778 - val_loss: 0.8055 - val_accuracy: 0.7800
# Epoch 4/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.2779 - accuracy: 0.9889 - val_loss: 0.7916 - val_accuracy: 0.7836
# Epoch 5/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.2233 - accuracy: 0.9889 - val_loss: 0.7518 - val_accuracy: 0.7851
# Epoch 6/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1797 - accuracy: 1.0000 - val_loss: 0.7874 - val_accuracy: 0.7588
# Epoch 7/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1555 - accuracy: 1.0000 - val_loss: 0.7392 - val_accuracy: 0.7756
# Epoch 8/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1339 - accuracy: 1.0000 - val_loss: 0.7561 - val_accuracy: 0.7661
# Epoch 9/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1179 - accuracy: 1.0000 - val_loss: 0.7176 - val_accuracy: 0.7778
# Epoch 10/300
# 23/23 [==============================] - 0s 18ms/step - loss: 0.1068 - accuracy: 1.0000 - val_loss: 0.7056 - val_accuracy: 0.7770
# Epoch 11/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0963 - accuracy: 1.0000 - val_loss: 0.6997 - val_accuracy: 0.7770
# Epoch 12/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.0866 - accuracy: 1.0000 - val_loss: 0.7122 - val_accuracy: 0.7734
# Epoch 13/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0794 - accuracy: 1.0000 - val_loss: 0.7010 - val_accuracy: 0.7727
# Epoch 14/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0734 - accuracy: 1.0000 - val_loss: 0.7006 - val_accuracy: 0.7675
# Epoch 15/300
# 23/23 [==============================] - 0s 18ms/step - loss: 0.0683 - accuracy: 1.0000 - val_loss: 0.6862 - val_accuracy: 0.7734
# Epoch 1/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.3010 - accuracy: 0.9304 - val_loss: 0.2646 - val_accuracy: 0.9306
# Epoch 2/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.1037 - accuracy: 0.9830 - val_loss: 0.2104 - val_accuracy: 0.9357
# Epoch 3/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0653 - accuracy: 0.9915 - val_loss: 0.2022 - val_accuracy: 0.9444
# Epoch 4/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0448 - accuracy: 0.9961 - val_loss: 0.1977 - val_accuracy: 0.9423
# Epoch 5/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0320 - accuracy: 0.9976 - val_loss: 0.1968 - val_accuracy: 0.9444
# Epoch 6/300
# 1350/1350 [==============================] - 3s 3ms/step - loss: 0.0231 - accuracy: 0.9987 - val_loss: 0.2009 - val_accuracy: 0.9452
# Epoch 7/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0175 - accuracy: 0.9989 - val_loss: 0.1961 - val_accuracy: 0.9415
# Epoch 8/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0134 - accuracy: 0.9993 - val_loss: 0.2024 - val_accuracy: 0.9466
# Epoch 9/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0098 - accuracy: 0.9998 - val_loss: 0.2065 - val_accuracy: 0.9466
# Epoch 10/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0078 - accuracy: 0.9998 - val_loss: 0.1931 - val_accuracy: 0.9452
# Epoch 11/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.2083 - val_accuracy: 0.9452
# Epoch 12/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9452
# Epoch 13/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2086 - val_accuracy: 0.9503
# Epoch 14/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2232 - val_accuracy: 0.9459
# Epoch 15/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2197 - val_accuracy: 0.9466
# Epoch 16/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2256 - val_accuracy: 0.9488
# Epoch 17/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 0.9466
# Epoch 18/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2413 - val_accuracy: 0.9459
# Epoch 19/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 9.5867e-04 - accuracy: 1.0000 - val_loss: 0.2460 - val_accuracy: 0.9459
# Epoch 20/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 7.7637e-04 - accuracy: 1.0000 - val_loss: 0.2530 - val_accuracy: 0.9452
# Epoch 21/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 6.0444e-04 - accuracy: 1.0000 - val_loss: 0.2501 - val_accuracy: 0.9466
# Epoch 22/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 5.0474e-04 - accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.9474
# Epoch 23/300
# 1350/1350 [==============================] - 3s 2ms/step - loss: 3.9792e-04 - accuracy: 1.0000 - val_loss: 0.2839 - val_accuracy: 0.9466
# Epoch 1/300
# 450/450 [==============================] - 2s 3ms/step - loss: 0.5210 - accuracy: 0.8683 - val_loss: 0.4006 - val_accuracy: 0.9006
# Epoch 2/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.1896 - accuracy: 0.9717 - val_loss: 0.3124 - val_accuracy: 0.9225
# Epoch 3/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.1315 - accuracy: 0.9844 - val_loss: 0.2936 - val_accuracy: 0.9232
# Epoch 4/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0996 - accuracy: 0.9900 - val_loss: 0.2824 - val_accuracy: 0.9306
# Epoch 5/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0786 - accuracy: 0.9933 - val_loss: 0.2550 - val_accuracy: 0.9320
# Epoch 6/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0640 - accuracy: 0.9961 - val_loss: 0.2643 - val_accuracy: 0.9298
# Epoch 7/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0529 - accuracy: 0.9967 - val_loss: 0.2461 - val_accuracy: 0.9371
# Epoch 8/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0441 - accuracy: 0.9978 - val_loss: 0.2455 - val_accuracy: 0.9342
# Epoch 9/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0371 - accuracy: 0.9994 - val_loss: 0.2318 - val_accuracy: 0.9386
# Epoch 10/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0312 - accuracy: 0.9989 - val_loss: 0.2378 - val_accuracy: 0.9371
# Epoch 11/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.2476 - val_accuracy: 0.9349
# Epoch 12/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0226 - accuracy: 0.9994 - val_loss: 0.2364 - val_accuracy: 0.9386
# Epoch 13/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.2488 - val_accuracy: 0.9342
# Epoch 14/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.2338 - val_accuracy: 0.9342
# Epoch 15/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.2316 - val_accuracy: 0.9371
# Epoch 16/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.2382 - val_accuracy: 0.9386
# Epoch 17/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.2520 - val_accuracy: 0.9386
# Epoch 18/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2432 - val_accuracy: 0.9364
# Epoch 19/300
# 450/450 [==============================] - 1s 3ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2453 - val_accuracy: 0.9379
# Epoch 1/300
# 270/270 [==============================] - 2s 5ms/step - loss: 0.6497 - accuracy: 0.8306 - val_loss: 0.4799 - val_accuracy: 0.8823
# Epoch 2/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.2386 - accuracy: 0.9713 - val_loss: 0.3612 - val_accuracy: 0.9072
# Epoch 3/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.1682 - accuracy: 0.9833 - val_loss: 0.3055 - val_accuracy: 0.9218
# Epoch 4/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.1288 - accuracy: 0.9917 - val_loss: 0.2859 - val_accuracy: 0.9291
# Epoch 5/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.1058 - accuracy: 0.9944 - val_loss: 0.2910 - val_accuracy: 0.9189
# Epoch 6/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0875 - accuracy: 0.9944 - val_loss: 0.2801 - val_accuracy: 0.9211
# Epoch 7/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0737 - accuracy: 0.9972 - val_loss: 0.2692 - val_accuracy: 0.9211
# Epoch 8/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0636 - accuracy: 0.9991 - val_loss: 0.2576 - val_accuracy: 0.9247
# Epoch 9/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0543 - accuracy: 0.9991 - val_loss: 0.2445 - val_accuracy: 0.9276
# Epoch 10/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0479 - accuracy: 0.9991 - val_loss: 0.2453 - val_accuracy: 0.9254
# Epoch 11/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0412 - accuracy: 1.0000 - val_loss: 0.2399 - val_accuracy: 0.9284
# Epoch 12/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.2300 - val_accuracy: 0.9284
# Epoch 13/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.2422 - val_accuracy: 0.9284
# Epoch 14/300
# 270/270 [==============================] - 1s 3ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.2310 - val_accuracy: 0.9284
# Epoch 1/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.7840 - accuracy: 0.7875 - val_loss: 0.5155 - val_accuracy: 0.8750
# Epoch 2/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.2801 - accuracy: 0.9611 - val_loss: 0.4336 - val_accuracy: 0.8984
# Epoch 3/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.1980 - accuracy: 0.9806 - val_loss: 0.3808 - val_accuracy: 0.9020
# Epoch 4/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1525 - accuracy: 0.9917 - val_loss: 0.3481 - val_accuracy: 0.9115
# Epoch 5/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1258 - accuracy: 0.9903 - val_loss: 0.3191 - val_accuracy: 0.9189
# Epoch 6/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.1048 - accuracy: 0.9944 - val_loss: 0.2999 - val_accuracy: 0.9254
# Epoch 7/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.0896 - accuracy: 0.9958 - val_loss: 0.3078 - val_accuracy: 0.9167
# Epoch 8/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0778 - accuracy: 1.0000 - val_loss: 0.2901 - val_accuracy: 0.9225
# Epoch 9/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0679 - accuracy: 0.9972 - val_loss: 0.2864 - val_accuracy: 0.9181
# Epoch 10/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0599 - accuracy: 1.0000 - val_loss: 0.2865 - val_accuracy: 0.9196
# Epoch 11/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.9247
# Epoch 12/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0483 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9247
# Epoch 13/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.2552 - val_accuracy: 0.9276
# Epoch 14/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.2615 - val_accuracy: 0.9218
# Epoch 15/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 0.2616 - val_accuracy: 0.9225
# Epoch 16/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.2534 - val_accuracy: 0.9225
# Epoch 17/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.2541 - val_accuracy: 0.9218
# Epoch 18/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.2506 - val_accuracy: 0.9240
# Epoch 19/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.2392 - val_accuracy: 0.9240
# Epoch 20/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.2387 - val_accuracy: 0.9276
# Epoch 21/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.2415 - val_accuracy: 0.9269
# Epoch 22/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.2416 - val_accuracy: 0.9269
# Epoch 23/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.2340 - val_accuracy: 0.9262
# Epoch 1/300
# 90/90 [==============================] - 1s 7ms/step - loss: 1.0763 - accuracy: 0.6861 - val_loss: 0.6589 - val_accuracy: 0.8326
# Epoch 2/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.3492 - accuracy: 0.9611 - val_loss: 0.5121 - val_accuracy: 0.8779
# Epoch 3/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.2470 - accuracy: 0.9806 - val_loss: 0.5300 - val_accuracy: 0.8582
# Epoch 4/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1903 - accuracy: 0.9917 - val_loss: 0.4845 - val_accuracy: 0.8699
# Epoch 5/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1532 - accuracy: 0.9972 - val_loss: 0.4112 - val_accuracy: 0.8904
# Epoch 6/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1298 - accuracy: 1.0000 - val_loss: 0.4467 - val_accuracy: 0.8816
# Epoch 7/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.1119 - accuracy: 1.0000 - val_loss: 0.3977 - val_accuracy: 0.8852
# Epoch 8/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0988 - accuracy: 1.0000 - val_loss: 0.3846 - val_accuracy: 0.8947
# Epoch 9/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0873 - accuracy: 1.0000 - val_loss: 0.3940 - val_accuracy: 0.8896
# Epoch 10/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0781 - accuracy: 1.0000 - val_loss: 0.3755 - val_accuracy: 0.8947
# Epoch 11/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0701 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.8874
# Epoch 12/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.3543 - val_accuracy: 0.8999
# Epoch 13/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0587 - accuracy: 1.0000 - val_loss: 0.3550 - val_accuracy: 0.8977
# Epoch 14/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0531 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.8867
# Epoch 15/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0488 - accuracy: 1.0000 - val_loss: 0.3466 - val_accuracy: 0.8969
# Epoch 16/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.3447 - val_accuracy: 0.8955
# Epoch 17/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.3500 - val_accuracy: 0.8925
# Epoch 18/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 0.3403 - val_accuracy: 0.8962
# Epoch 19/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.8962
# Epoch 20/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0340 - accuracy: 1.0000 - val_loss: 0.3305 - val_accuracy: 0.8991
# Epoch 21/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.3342 - val_accuracy: 0.8977
# Epoch 22/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0297 - accuracy: 1.0000 - val_loss: 0.3319 - val_accuracy: 0.8969
# Epoch 1/300
# 45/45 [==============================] - 1s 13ms/step - loss: 1.4815 - accuracy: 0.4889 - val_loss: 1.0142 - val_accuracy: 0.6513
# Epoch 2/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.5206 - accuracy: 0.9278 - val_loss: 0.7092 - val_accuracy: 0.8260
# Epoch 3/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.3347 - accuracy: 0.9611 - val_loss: 0.6805 - val_accuracy: 0.8319
# Epoch 4/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2562 - accuracy: 0.9944 - val_loss: 0.6230 - val_accuracy: 0.8268
# Epoch 5/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.2040 - accuracy: 1.0000 - val_loss: 0.6158 - val_accuracy: 0.8216
# Epoch 6/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.1735 - accuracy: 1.0000 - val_loss: 0.5926 - val_accuracy: 0.8370
# Epoch 7/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1493 - accuracy: 1.0000 - val_loss: 0.5553 - val_accuracy: 0.8436
# Epoch 8/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.1295 - accuracy: 1.0000 - val_loss: 0.5640 - val_accuracy: 0.8377
# Epoch 9/300
# 45/45 [==============================] - 1s 16ms/step - loss: 0.1151 - accuracy: 1.0000 - val_loss: 0.5550 - val_accuracy: 0.8399
# Epoch 10/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.1040 - accuracy: 1.0000 - val_loss: 0.5443 - val_accuracy: 0.8377
# Epoch 11/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0931 - accuracy: 1.0000 - val_loss: 0.5324 - val_accuracy: 0.8370
# Epoch 12/300
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0846 - accuracy: 1.0000 - val_loss: 0.5267 - val_accuracy: 0.8392
# Epoch 13/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0781 - accuracy: 1.0000 - val_loss: 0.5297 - val_accuracy: 0.8385
# Epoch 14/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0719 - accuracy: 1.0000 - val_loss: 0.5093 - val_accuracy: 0.8458
# Epoch 15/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0667 - accuracy: 1.0000 - val_loss: 0.5114 - val_accuracy: 0.8392
# Epoch 16/300
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0630 - accuracy: 1.0000 - val_loss: 0.5115 - val_accuracy: 0.8385
# Epoch 17/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0586 - accuracy: 1.0000 - val_loss: 0.5137 - val_accuracy: 0.8406
# Epoch 18/300
# 45/45 [==============================] - 1s 16ms/step - loss: 0.0546 - accuracy: 1.0000 - val_loss: 0.5011 - val_accuracy: 0.8421
# Epoch 19/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0511 - accuracy: 1.0000 - val_loss: 0.4983 - val_accuracy: 0.8406
# Epoch 20/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0484 - accuracy: 1.0000 - val_loss: 0.4956 - val_accuracy: 0.8406
# Epoch 21/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0452 - accuracy: 1.0000 - val_loss: 0.4888 - val_accuracy: 0.8392
# Epoch 22/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.4939 - val_accuracy: 0.8392
# Epoch 23/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0405 - accuracy: 1.0000 - val_loss: 0.4859 - val_accuracy: 0.8392
# Epoch 24/300
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0391 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.8414
# Epoch 1/300
# 23/23 [==============================] - 1s 26ms/step - loss: 1.8347 - accuracy: 0.3889 - val_loss: 1.2554 - val_accuracy: 0.5848
# Epoch 2/300
# ...
# Epoch 32/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2374 - val_accuracy: 0.9291
# Epoch 33/300
# 270/270 [==============================] - 1s 4ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2351 - val_accuracy: 0.9298
# Epoch 1/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.7857 - accuracy: 0.7681 - val_loss: 0.5196 - val_accuracy: 0.8882
# Epoch 2/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.2702 - accuracy: 0.9694 - val_loss: 0.4034 - val_accuracy: 0.9028
# Epoch 3/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.1895 - accuracy: 0.9861 - val_loss: 0.3878 - val_accuracy: 0.8962
# Epoch 4/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.1432 - accuracy: 0.9972 - val_loss: 0.3468 - val_accuracy: 0.9101
# Epoch 5/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.1174 - accuracy: 0.9958 - val_loss: 0.3335 - val_accuracy: 0.9064
# Epoch 6/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0976 - accuracy: 0.9986 - val_loss: 0.3125 - val_accuracy: 0.9101
# Epoch 7/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0828 - accuracy: 0.9986 - val_loss: 0.3083 - val_accuracy: 0.9101
# Epoch 8/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0713 - accuracy: 0.9986 - val_loss: 0.2974 - val_accuracy: 0.9115
# Epoch 9/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0630 - accuracy: 1.0000 - val_loss: 0.2876 - val_accuracy: 0.9094
# Epoch 10/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.2996 - val_accuracy: 0.9115
# Epoch 11/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.0491 - accuracy: 0.9986 - val_loss: 0.2816 - val_accuracy: 0.9130
# Epoch 12/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9130
# Epoch 13/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 0.2877 - val_accuracy: 0.9130
# Epoch 14/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 0.2812 - val_accuracy: 0.9159
# Epoch 15/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.2793 - val_accuracy: 0.9174
# Epoch 16/300
# 180/180 [==============================] - 1s 5ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.2760 - val_accuracy: 0.9152
# Epoch 17/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.2732 - val_accuracy: 0.9152
# Epoch 18/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.2756 - val_accuracy: 0.9145
# Epoch 19/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.2757 - val_accuracy: 0.9152
# Epoch 20/300
# 180/180 [==============================] - 1s 6ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.2758 - val_accuracy: 0.9152
# Epoch 21/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.9152
# Epoch 22/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.2716 - val_accuracy: 0.9167
# Epoch 23/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.2679 - val_accuracy: 0.9167
# Epoch 24/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.2701 - val_accuracy: 0.9174
# Epoch 25/300
# 180/180 [==============================] - 1s 4ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.2773 - val_accuracy: 0.9167
# Epoch 1/300
# 90/90 [==============================] - 1s 8ms/step - loss: 1.0724 - accuracy: 0.6889 - val_loss: 0.6112 - val_accuracy: 0.8648
# Epoch 2/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.3351 - accuracy: 0.9694 - val_loss: 0.5303 - val_accuracy: 0.8684
# Epoch 3/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.2346 - accuracy: 0.9722 - val_loss: 0.5155 - val_accuracy: 0.8618
# Epoch 4/300
# 90/90 [==============================] - 1s 10ms/step - loss: 0.1758 - accuracy: 0.9889 - val_loss: 0.4643 - val_accuracy: 0.8728
# Epoch 5/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.1446 - accuracy: 0.9944 - val_loss: 0.4452 - val_accuracy: 0.8801
# Epoch 6/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.1221 - accuracy: 1.0000 - val_loss: 0.4572 - val_accuracy: 0.8633
# Epoch 7/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.1041 - accuracy: 0.9972 - val_loss: 0.4322 - val_accuracy: 0.8692
# Epoch 8/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0920 - accuracy: 1.0000 - val_loss: 0.4120 - val_accuracy: 0.8794
# Epoch 9/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0803 - accuracy: 1.0000 - val_loss: 0.4139 - val_accuracy: 0.8772
# Epoch 10/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0722 - accuracy: 1.0000 - val_loss: 0.4189 - val_accuracy: 0.8735
# Epoch 11/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0648 - accuracy: 1.0000 - val_loss: 0.4114 - val_accuracy: 0.8743
# Epoch 12/300
# 90/90 [==============================] - 1s 10ms/step - loss: 0.0585 - accuracy: 1.0000 - val_loss: 0.3963 - val_accuracy: 0.8823
# Epoch 13/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.3991 - val_accuracy: 0.8772
# Epoch 14/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0491 - accuracy: 1.0000 - val_loss: 0.4037 - val_accuracy: 0.8765
# Epoch 15/300
# 90/90 [==============================] - 1s 10ms/step - loss: 0.0456 - accuracy: 1.0000 - val_loss: 0.3979 - val_accuracy: 0.8765
# Epoch 16/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0416 - accuracy: 1.0000 - val_loss: 0.4044 - val_accuracy: 0.8743
# Epoch 17/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.4061 - val_accuracy: 0.8721
# Epoch 18/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 0.3943 - val_accuracy: 0.8772
# Epoch 19/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.3889 - val_accuracy: 0.8794
# Epoch 20/300
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.3926 - val_accuracy: 0.8787
# Epoch 21/300
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.3959 - val_accuracy: 0.8801
# Epoch 22/300
# 90/90 [==============================] - 1s 9ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.3893 - val_accuracy: 0.8794
# Epoch 1/300
# 45/45 [==============================] - 1s 14ms/step - loss: 1.4328 - accuracy: 0.5056 - val_loss: 0.9830 - val_accuracy: 0.6944
# Epoch 2/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.4968 - accuracy: 0.9278 - val_loss: 0.7112 - val_accuracy: 0.8282
# Epoch 3/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.3075 - accuracy: 0.9889 - val_loss: 0.6446 - val_accuracy: 0.8289
# Epoch 4/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.2372 - accuracy: 0.9889 - val_loss: 0.5887 - val_accuracy: 0.8523
# Epoch 5/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.1884 - accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 0.8304
# Epoch 6/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.1564 - accuracy: 1.0000 - val_loss: 0.5706 - val_accuracy: 0.8341
# Epoch 7/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.1355 - accuracy: 1.0000 - val_loss: 0.5322 - val_accuracy: 0.8523
# Epoch 8/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.1184 - accuracy: 1.0000 - val_loss: 0.5431 - val_accuracy: 0.8450
# Epoch 9/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.1049 - accuracy: 1.0000 - val_loss: 0.5199 - val_accuracy: 0.8523
# Epoch 10/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0939 - accuracy: 1.0000 - val_loss: 0.5198 - val_accuracy: 0.8480
# Epoch 11/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0847 - accuracy: 1.0000 - val_loss: 0.5208 - val_accuracy: 0.8458
# Epoch 12/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0770 - accuracy: 1.0000 - val_loss: 0.5026 - val_accuracy: 0.8560
# Epoch 13/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0706 - accuracy: 1.0000 - val_loss: 0.5088 - val_accuracy: 0.8523
# Epoch 14/300
# 45/45 [==============================] - 1s 13ms/step - loss: 0.0651 - accuracy: 1.0000 - val_loss: 0.5016 - val_accuracy: 0.8553
# Epoch 15/300
# 45/45 [==============================] - 1s 13ms/step - loss: 0.0606 - accuracy: 1.0000 - val_loss: 0.4982 - val_accuracy: 0.8575
# Epoch 16/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0565 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.8509
# Epoch 17/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0530 - accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.8487
# Epoch 18/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.4903 - val_accuracy: 0.8582
# Epoch 19/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0462 - accuracy: 1.0000 - val_loss: 0.4931 - val_accuracy: 0.8553
# Epoch 20/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.8567
# Epoch 21/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.4883 - val_accuracy: 0.8582
# Epoch 22/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0389 - accuracy: 1.0000 - val_loss: 0.4921 - val_accuracy: 0.8575
# Epoch 23/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.4840 - val_accuracy: 0.8589
# Epoch 24/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.4830 - val_accuracy: 0.8596
# Epoch 25/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.4873 - val_accuracy: 0.8596
# Epoch 26/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.4883 - val_accuracy: 0.8538
# Epoch 27/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.4844 - val_accuracy: 0.8582
# Epoch 28/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.4864 - val_accuracy: 0.8575
# Epoch 29/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.4849 - val_accuracy: 0.8582
# Epoch 30/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.4767 - val_accuracy: 0.8604
# Epoch 31/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.4825 - val_accuracy: 0.8575
# Epoch 32/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.4872 - val_accuracy: 0.8575
# Epoch 33/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.4861 - val_accuracy: 0.8553
# Epoch 34/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.4780 - val_accuracy: 0.8604
# Epoch 35/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.4867 - val_accuracy: 0.8560
# Epoch 36/300
# 45/45 [==============================] - 1s 17ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.8582
# Epoch 37/300
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.4782 - val_accuracy: 0.8589
# Epoch 38/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.4810 - val_accuracy: 0.8604
# Epoch 39/300
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.4848 - val_accuracy: 0.8596
# Epoch 40/300
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.4805 - val_accuracy: 0.8582
# Epoch 1/300
# 23/23 [==============================] - 1s 37ms/step - loss: 1.9177 - accuracy: 0.3111 - val_loss: 1.2174 - val_accuracy: 0.6499
# Epoch 2/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.6573 - accuracy: 0.9111 - val_loss: 0.9372 - val_accuracy: 0.7361
# Epoch 3/300
# 23/23 [==============================] - 1s 33ms/step - loss: 0.3688 - accuracy: 0.9778 - val_loss: 0.8201 - val_accuracy: 0.7668
# Epoch 4/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.2678 - accuracy: 0.9778 - val_loss: 0.7957 - val_accuracy: 0.7705
# Epoch 5/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.2132 - accuracy: 0.9889 - val_loss: 0.7581 - val_accuracy: 0.7829
# Epoch 6/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.1809 - accuracy: 1.0000 - val_loss: 0.7991 - val_accuracy: 0.7522
# Epoch 7/300
# 23/23 [==============================] - 0s 19ms/step - loss: 0.1576 - accuracy: 1.0000 - val_loss: 0.7335 - val_accuracy: 0.7829
# Epoch 8/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.1323 - accuracy: 1.0000 - val_loss: 0.7651 - val_accuracy: 0.7632
# Epoch 9/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.1185 - accuracy: 1.0000 - val_loss: 0.7128 - val_accuracy: 0.7807
# Epoch 10/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.1068 - accuracy: 1.0000 - val_loss: 0.7206 - val_accuracy: 0.7778
# Epoch 11/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0958 - accuracy: 1.0000 - val_loss: 0.7101 - val_accuracy: 0.7785
# Epoch 12/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0875 - accuracy: 1.0000 - val_loss: 0.6977 - val_accuracy: 0.7851
# Epoch 13/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0807 - accuracy: 1.0000 - val_loss: 0.6805 - val_accuracy: 0.7917
# Epoch 14/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0752 - accuracy: 1.0000 - val_loss: 0.6890 - val_accuracy: 0.7851
# Epoch 15/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0691 - accuracy: 1.0000 - val_loss: 0.6798 - val_accuracy: 0.7902
# Epoch 16/300
# 23/23 [==============================] - 1s 31ms/step - loss: 0.0644 - accuracy: 1.0000 - val_loss: 0.6943 - val_accuracy: 0.7807
# Epoch 17/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.6861 - val_accuracy: 0.7858
# Epoch 18/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0571 - accuracy: 1.0000 - val_loss: 0.6785 - val_accuracy: 0.7880
# Epoch 19/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.6816 - val_accuracy: 0.7851
# Epoch 20/300
# 23/23 [==============================] - 0s 20ms/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 0.6724 - val_accuracy: 0.7858
# Epoch 21/300
# 23/23 [==============================] - 1s 32ms/step - loss: 0.0478 - accuracy: 1.0000 - val_loss: 0.6768 - val_accuracy: 0.7851
# Epoch 22/300
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0456 - accuracy: 1.0000 - val_loss: 0.6678 - val_accuracy: 0.7895
# Epoch 23/300
# 23/23 [==============================] - 0s 22ms/step - loss: 0.0434 - accuracy: 1.0000 - val_loss: 0.6682 - val_accuracy: 0.7895
